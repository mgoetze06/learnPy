# %%
import requests
import urllib3
from strava_secrets_request import getFullHeaderWithAccessToken
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)



auth_url = "https://www.strava.com/oauth/token"
activites_url = "https://www.strava.com/api/v3/athlete/activities"

header = getFullHeaderWithAccessToken()

request_page_num = 1
all_activities = []

while True:
    param = {'per_page': 50, 'page': request_page_num}
    # initial request, where we request the first page of activities
    my_dataset = requests.get(activites_url, headers=header, params=param).json()

    # check the response to make sure it is not empty. If it is empty, that means there is no more data left. So if you have
    # 1000 activities, on the 6th request, where we request page 6, there would be no more data left, so we will break out of the loop
    if len(my_dataset) == 0:
        print("breaking out of while loop because the response is zero, which means there must be no more activities")
        break

    # if the all_activities list is already populated, that means we want to add additional data to it via extend.
    if all_activities:
        print("all_activities is populated")
        all_activities.extend(my_dataset)

    # if the all_activities is empty, this is the first time adding data so we just set it equal to my_dataset
    else:
        print("all_activities is NOT populated")
        all_activities = my_dataset

    request_page_num += 1
# Out:
# Requesting Token...
#
# all_activities is NOT populated
# all_activities is populated
# all_activities is populated
# all_activities is populated
# breaking out of while loop because the response is zero, which means there must be no more activities

# %%
print(len(all_activities))
for count, activity in enumerate(all_activities):
    print(activity["name"])
    print(count)
# Out:
# 174
# Radfahrt am Abend
# 0
# Radfahrt am Nachmittag
# 1
# Radfahrt am Nachmittag
# 2
# Radfahrt am Morgen
# 3
# Fahrt am Nachmittag
# 4
# Fahrt am Nachmittag
# 5
# Abendradfahrt
# 6
# Radfahrt am Nachmittag
# 7
# Radfahrt am Abend
# 8
# Radfahrt am Mittag
# 9
# Radfahrt am Nachmittag
# 10
# Radfahrt am Abend
# 11
# Radfahrt am Abend
# 12
# Radfahrt am Mittag
# 13
# Fahrt am Nachmittag
# 14
# Fahrt am Nachmittag
# 15
# Radfahrt am Abend
# 16
# Radfahrt am Abend
# 17
# Firmenlauf Leipzig 2025
# 18
# Radfahrt am Morgen
# 19
# Lauf am Abend
# 20
# Radfahrt am Abend
# 21
# Radfahrt am Morgen
# 22
# Radfahrt am Nachmittag
# 23
# Radfahrt am Nachmittag
# 24
# Abendradfahrt
# 25
# Abendradfahrt
# 26
# Lauf am Abend
# 27
# Radfahrt am Mittag
# 28
# Fahrt am Nachmittag
# 29
# Pfingstfahrt
# 30
# Fahrt am Morgen
# 31
# Fahrt am Morgen
# 32
# Fahrt am Morgen
# 33
# Fahrt am Nachmittag
# 34
# Fahrt am Morgen
# 35
# Radfahrt am Morgen
# 36
# Radfahrt am Abend
# 37
# Radfahrt am Morgen
# 38
# Dorn am Abend
# 39
# Platten im Regen
# 40
# Fahrt am Nachmittag
# 41
# Kleiner Feierabendsprint
# 42
# Fahrt am Nachmittag
# 43
# Radfahrt am Nachmittag
# 44
# Radfahrt am Nachmittag
# 45
# New Bike Day
# 46
# Automatisierung am Nachmittag
# 47
# Radfahrt am Morgen
# 48
# Radfahrt am Nachmittag
# 49
# Entspannte Feierabendrunde
# 50
# Mini OKF
# 51
# Radfahrt am Mittag
# 52
# Tour am 1. Mai
# 53
# Radfahrt am Abend
# 54
# Fahrt nach Tornau
# 55
# Montagsgravel
# 56
# Wanderung am Mittag
# 57
# Wanderung am Morgen
# 58
# Wanderung am Morgen
# 59
# Mini-Feierabendrunde
# 60
# Radfahrt am Nachmittag
# 61
# Radfahrt am Nachmittag
# 62
# Radfahrt am Nachmittag
# 63
# Bitterfeld noch nicht komplett im Arsch
# 64
# Tour de Eierlikör
# 65
# Ostertour
# 66
# OKF
# 67
# Regeneration II / OKF
# 68
# Regeneration
# 69
# Mittagsradfahrt
# 70
# Vollgas für Werni
# 71
# Fahrt am Nachmittag
# 72
# Fahrt am Nachmittag
# 73
# Der Wind ist mein Berg
# 74
# Going Home
# 75
# Brüderliche Seenrunde
# 76
# Seenrunde
# 77
# Mulderadweg entdecken
# 78
# Feierabend im Regen und am Ende geht die Luft aus
# 79
# Feierabend im Regen
# 80
# Neues Cube abholen
# 81
# Fahrt am Nachmittag
# 82
# Fahrt am Nachmittag
# 83
# Fahrt am Nachmittag
# 84
# Lauf am Nachmittag
# 85
# Fahrt am Nachmittag
# 86
# Waldwege im Januar
# 87
# Fahrt am Nachmittag
# 88
# Lauf am Nachmittag
# 89
# Lauf am Abend
# 90
# Lauf am Nachmittag
# 91
# Die 10 in Sicht
# 92
# Lauf am Nachmittag
# 93
# Lauf am Morgen
# 94
# Ischgl
# 95
# Fahrt am Nachmittag
# 96
# Lauf am Nachmittag
# 97
# Durchhalten
# 98
# Mittwochsrunde
# 99
# Wanderung am Morgen
# 100
# Radfahrt am Nachmittag
# 101
# Radfahrt am Nachmittag
# 102
# Radfahrt der Sackgassen
# 103
# Inline-Skating-Einheit am Nachmittag
# 104
# Radfahrt am Nachmittag
# 105
# Lauf am Abend
# 106
# Fahrt am Nachmittag
# 107
# Lauf am Nachmittag
# 108
# Lauf am Nachmittag
# 109
# Mit Rückenwind
# 110
# Inliner-Retter
# 111
# Fahrt am Morgen
# 112
# Durchhalten
# 113
# Radfahrt am Nachmittag
# 114
# Radfahrt am Mittag
# 115
# Lauf am Abend
# 116
# Lauf am Abend
# 117
# Lauf am Abend
# 118
# Ich war auch beim Sputnik
# 119
# Pfingstlauf
# 120
# Lauf
# 121
# Fahrt am Morgen
# 122
# Fahrt am Morgen
# 123
# BTF nach Kanena
# 124
# Fahrt am Morgen
# 125
# Lauf am Abend
# 126
# Lauf am Abend
# 127
# Fahrt am Nachmittag
# 128
# Lauf am Abend
# 129
# Lauf am Abend
# 130
# Radfahrt am Nachmittag
# 131
# Radfahrt am Nachmittag
# 132
# Radfahrt am Mittag
# 133
# Lauf am Mittag
# 134
# Lauf am Nachmittag
# 135
# Lauf am Abend
# 136
# Lauf am Abend
# 137
# Lauf am Nachmittag
# 138
# Lauf am Abend
# 139
# Lauf am Mittag
# 140
# Lauf am Abend
# 141
# Lauf am Mittag
# 142
# Lauf am Mittag
# 143
# Lauf am Abend
# 144
# Lauf am Mittag
# 145
# Lauf am Abend
# 146
# Lauf am Abend
# 147
# Mittagswanderung
# 148
# Firmenlauf
# 149
# Abendlauf
# 150
# Lauf am Mittag
# 151
# Radfahrt am Nachmittag
# 152
# Inline-Skating-Einheit zur Mittagszeit
# 153
# Inline-Skating-Einheit am Morgen
# 154
# Lauf am Abend
# 155
# Lauf am Abend
# 156
# Lauf am Abend
# 157
# Lauf am Abend
# 158
# Inline-Skating-Einheit am Nachmittag
# 159
# Lauf am Abend
# 160
# Lauf am Nachmittag
# 161
# Lauf am Mittag
# 162
# Lauf am Nachmittag
# 163
# Lauf am Mittag
# 164
# Strandlauf
# 165
# Lauf am Mittag
# 166
# Lauf am Abend
# 167
# Lauf am Nachmittag
# 168
# Lauf am Nachmittag
# 169
# Lauf am Morgen
# 170
# Lauf am Nachmittag
# 171
# Lauf am Morgen
# 172
# Lauf am Morgen
# 173

# %%
import pandas as pd
from pandas import json_normalize

activities = json_normalize(all_activities)
activities.columns
# Out:
# Index(['resource_state', 'name', 'distance', 'moving_time', 'elapsed_time',
#        'total_elevation_gain', 'type', 'sport_type', 'workout_type', 'id',
#        'start_date', 'start_date_local', 'timezone', 'utc_offset',
#        'location_city', 'location_state', 'location_country',
#        'achievement_count', 'kudos_count', 'comment_count', 'athlete_count',
#        'photo_count', 'trainer', 'commute', 'manual', 'private', 'visibility',
#        'flagged', 'gear_id', 'start_latlng', 'end_latlng', 'average_speed',
#        'max_speed', 'average_watts', 'device_watts', 'kilojoules',
#        'has_heartrate', 'heartrate_opt_out', 'display_hide_heartrate_option',
#        'elev_high', 'elev_low', 'upload_id', 'upload_id_str', 'external_id',
#        'from_accepted_tag', 'pr_count', 'total_photo_count', 'has_kudoed',
#        'athlete.id', 'athlete.resource_state', 'map.id',
#        'map.summary_polyline', 'map.resource_state'],
#       dtype='object')

# %%
activities.head(3)
# Out:
#    resource_state                    name  distance  moving_time  \
# 0               2       Radfahrt am Abend   32518.2         4381
# 1               2  Radfahrt am Nachmittag   41461.8         5561
# 2               2  Radfahrt am Nachmittag   73895.6        11091
#
#    elapsed_time  total_elevation_gain  type sport_type  workout_type  \
# 0          4583                  97.2  Ride       Ride          10.0
# 1          5869                  96.9  Ride       Ride          10.0
# 2         12353                 278.5  Ride       Ride          10.0
#
#             id  ...                                        external_id  \
# 0  15189301407  ...  c9d40515-c4fb-4890-a33c-05030a5693c4-activity.fit
# 1  15179031643  ...  d6594631-fa79-4421-ab68-8fc79f4ddbd2-activity.fit
# 2  15156393829  ...  aa8654b6-ebe3-4c97-851c-9318eb2aa6d1-activity.fit
#
#   from_accepted_tag pr_count  total_photo_count has_kudoed athlete.id  \
# 0             False        0                  0      False   30248736
# 1             False        2                  0      False   30248736
# 2             False        2                  1      False   30248736
#
#   athlete.resource_state        map.id  \
# 0                      1  a15189301407
# 1                      1  a15179031643
# 2                      1  a15156393829
#
#                                 map.summary_polyline  map.resource_state
# 0  eadzHotdjAdAyET]~@l@p@t@bBlCPd@L@pAoCpImNfCqCz...                   2
# 1  {adzH}sdjATQ`AyE\W|ApAnBvCXF`MeTkCrCsAwIW[{I`D...                   2
# 2  gadzHstdjA`BoFdFpFfMgTwClCcBiJyOtGsGo@k@aAqDqP...                   2
#
# [3 rows x 53 columns]

# %%
rides = activities.loc[activities['type'] == 'Ride']
runs = activities.loc[activities['type'] == 'Run']

# %%
rides.head(3)
# Out:
#    resource_state                    name  distance  moving_time  \
# 0               2       Radfahrt am Abend   32518.2         4381
# 1               2  Radfahrt am Nachmittag   41461.8         5561
# 2               2  Radfahrt am Nachmittag   73895.6        11091
#
#    elapsed_time  total_elevation_gain  type sport_type  workout_type  \
# 0          4583                  97.2  Ride       Ride          10.0
# 1          5869                  96.9  Ride       Ride          10.0
# 2         12353                 278.5  Ride       Ride          10.0
#
#             id  ...                                        external_id  \
# 0  15189301407  ...  c9d40515-c4fb-4890-a33c-05030a5693c4-activity.fit
# 1  15179031643  ...  d6594631-fa79-4421-ab68-8fc79f4ddbd2-activity.fit
# 2  15156393829  ...  aa8654b6-ebe3-4c97-851c-9318eb2aa6d1-activity.fit
#
#   from_accepted_tag pr_count  total_photo_count has_kudoed athlete.id  \
# 0             False        0                  0      False   30248736
# 1             False        2                  0      False   30248736
# 2             False        2                  1      False   30248736
#
#   athlete.resource_state        map.id  \
# 0                      1  a15189301407
# 1                      1  a15179031643
# 2                      1  a15156393829
#
#                                 map.summary_polyline  map.resource_state
# 0  eadzHotdjAdAyET]~@l@p@t@bBlCPd@L@pAoCpImNfCqCz...                   2
# 1  {adzH}sdjATQ`AyE\W|ApAnBvCXF`MeTkCrCsAwIW[{I`D...                   2
# 2  gadzHstdjA`BoFdFpFfMgTwClCcBiJyOtGsGo@k@aAqDqP...                   2
#
# [3 rows x 53 columns]

# %%
sum(rides["distance"])/1000
# Out:
# 2001.9564000000005

# %%
rides["start_date_local"]
# Out:
# 0      2025-05-21T18:09:00Z
# 1      2025-05-19T17:24:02Z
# 2      2025-05-19T15:34:42Z
# 3      2025-05-16T17:48:10Z
# 4      2025-05-15T17:46:25Z
#                ...
# 86     2024-04-07T13:40:29Z
# 89     2024-02-25T14:17:31Z
# 90     2024-02-18T13:38:04Z
# 91     2024-01-28T12:49:31Z
# 110    2023-06-21T14:34:30Z
# Name: start_date_local, Length: 63, dtype: object

# %%
from datetime import datetime
now = datetime.now()
current_month = now.strftime("%Y-%m")
current_month_rides = rides[rides['start_date_local'].str.contains(current_month, na=False)]
#current_month_rides['start_date_local'] = pd.to_datetime(rides['start_date_local'])
#current_month_rides.loc[current_month_rides['start_date_local'] ]
current_month_rides
sum(current_month_rides["distance"])/1000
# Out:
# 421.4076000000001

# %%
print(current_month_rides["average_speed"].mean() * 3.6)
print(current_month_rides["distance"].mean()/1000)
# Out:
# 23.477999999999998
# 35.1173

# %%
max(rides['average_speed']) * 3.6
# Out:
# 31.4064

# %%
last_ride = rides.loc[0]
last_ride
# Out:
# resource_state                                                                   2
# name                                                             Radfahrt am Abend
# distance                                                                   32518.2
# moving_time                                                                   4381
# elapsed_time                                                                  4583
# total_elevation_gain                                                          97.2
# type                                                                          Ride
# sport_type                                                                    Ride
# workout_type                                                                  10.0
# id                                                                     15189301407
# start_date                                                    2025-07-21T16:41:29Z
# start_date_local                                              2025-07-21T18:41:29Z
# timezone                                                 (GMT+01:00) Europe/Berlin
# utc_offset                                                                  7200.0
# location_city                                                                 None
# location_state                                                                None
# location_country                                                              None
# achievement_count                                                                3
# kudos_count                                                                      0
# comment_count                                                                    0
# athlete_count                                                                    1
# photo_count                                                                      0
# trainer                                                                      False
# commute                                                                      False
# manual                                                                       False
# private                                                                      False
# visibility                                                                everyone
# flagged                                                                      False
# gear_id                                                                  b15758359
# start_latlng                                                [51.638525, 12.318164]
# end_latlng                                                  [51.638587, 12.318205]
# average_speed                                                                7.423
# max_speed                                                                    10.96
# average_watts                                                                198.0
# device_watts                                                                 False
# kilojoules                                                                   867.2
# has_heartrate                                                                False
# heartrate_opt_out                                                            False
# display_hide_heartrate_option                                                False
# elev_high                                                                     95.0
# elev_low                                                                      70.8
# upload_id                                                            16220642709.0
# upload_id_str                                                          16220642709
# external_id                      c9d40515-c4fb-4890-a33c-05030a5693c4-activity.fit
# from_accepted_tag                                                            False
# pr_count                                                                         0
# total_photo_count                                                                0
# has_kudoed                                                                   False
# athlete.id                                                                30248736
# athlete.resource_state                                                           1
# map.id                                                                a15189301407
# map.summary_polyline             eadzHotdjAdAyET]~@l@p@t@bBlCPd@L@pAoCpImNfCqCz...
# map.resource_state                                                               2
# Name: 0, dtype: object

# %%
start_time_and_date = last_ride['start_date_local'].replace("-","_").replace("T","_").replace(":","_").replace("Z","")
print(start_time_and_date)
# Out:
# 2025_07_21_18_41_29

# %%
import wget
id = str(last_ride['id'])
print(id)
gpx_download_url = "https://www.strava.com/activities/<id>/export_gpx".replace("<id>",id)
print(gpx_download_url)
auth_url = "https://www.strava.com/oauth/token"

header = getFullHeaderWithAccessToken()
param = {'per_page': 50, 'page': 1}
r = requests.get(gpx_download_url, headers=header, params=param)
open(start_time_and_date , 'wb').write(r.content)
# Out:
# 15189301407
# https://www.strava.com/activities/15189301407/export_gpx
# Requesting Token...
# 919
