# %%
import gpxpy
import gpxpy.gpx
import numpy as np
import folium
import json
import os

# %%
def getMapCenter():
    lat = 51.5969943
    lon = 12.3482471

    return lat,lon

def getLocation(immo):

    #lat = 51.542011
    #lon = 12.4234463

    lat = immo["lat"]
    lon = immo["lon"]
    return lat,lon

def getTitle(immo):

    title = immo["title"]
    return title

def getLocationAdress(immo):

    street = immo["address"]
    city = immo["city"]
    address = street + " " + city
    return address

def getPrice(immo):

    return immo["price"]

def getLivingArea(immo):
    return immo["livingarea"]

def getPropertyArea(immo):
    return immo["propertyarea"]

def getYearOfConstruction(immo):
    return immo["constructionyear"]

def getLink(immo):
    return immo["link"]

def getTitleFilename(immo):
    id = str(immo["id"])

    filename = "title_"+id
    extension = getFileExtension(filename)
    file = "static/images/"+filename+extension
    print(file)
    return file

def getFileExtension(filename):
    files = os.listdir("static/images/")
    for path in files:
        if filename in path:
            return os.path.splitext(path)[1]

# %%
lat,lon = getMapCenter()
map = folium.Map(
    location=[lat, lon],
    zoom_start=11,
    tiles='OpenStreetMap'
)
with open('immo.json', encoding='utf-8') as f:
    immos = json.load(f)
    #print(d)

for immo in immos["immos"]:
    print(immo)
    popuphtml = "<h1>" + getTitle(immo) + "</h1><br>"
    popuphtml = popuphtml + "<table>"
    popuphtml = popuphtml + "<tr><td>Preis</td><td>" + str(getPrice(immo)) + " €</td></tr>"
    popuphtml = popuphtml + "<tr><td>Wohnfläche</td><td>" + str(getLivingArea(immo)) + " m^2</td></tr>"
    popuphtml = popuphtml + "<tr><td>Grundstücksfläche</td><td>" + str(getPropertyArea(immo)) + " m^2</td></tr>"
    popuphtml = popuphtml + "<tr><td>Baujahr</td><td>" + str(getYearOfConstruction(immo)) + "</td></tr>"
    popuphtml = popuphtml + "<tr><td>Adresse</td><td>" + str(getLocationAdress(immo)) + "</td></tr>"
    popuphtml = popuphtml + "</table>"
    popuphtml = popuphtml + "<a href=" + getLink(immo) + ">"+getLink(immo)+"</a>"
    popuphtml = popuphtml + "<a href=" + getLink(immo) + ">"
    popuphtml = popuphtml + "<img src='"+getTitleFilename(immo)+"'></a>"

    lat,lon = getLocation(immo)
    marker = folium.Marker(
                location=(lat,lon),
                icon=folium.Icon(icon='home'),
                tooltip=getTitle(immo),
                popup=folium.Popup(popuphtml),
            )
    marker.add_to(map)

with open('arbeit.json', encoding='utf-8') as f:
    work = json.load(f)
    #print(d)

for workplace in work["work"]:
    print(workplace)

    lat,lon = getLocation(workplace)
    marker = folium.Marker(
                location=(lat,lon),
                icon=folium.Icon(color="orange",icon='flag'),
                tooltip=workplace["name"]
            )
    marker.add_to(map)

with open('bahn.json', encoding='utf-8') as f:
    bahn = json.load(f)
    #print(d)

for station in bahn["stations"]:
    print(station)

    lat,lon = getLocation(station)
    marker = folium.Marker(
                location=(lat,lon),
                icon=folium.Icon(color="red",icon='info-sign'),
                tooltip=station["name"]
            )
    marker.add_to(map)

map
map.save('templates/map.html')
# Out:
# {'id': 0, 'title': 'Wohnen im Grünen: Idyllisches Einfamilienhaus in Spröda', 'price': 200000, 'city': '04509 Delitzsch OT Spröda', 'address': 'Waldblick 4', 'lat': 51.542011, 'lon': 12.4234463, 'ad_date': '15.01.2025', 'description': 'Das Haus wurde im Jahr 1984 erbaut und befindet sich auf einem großzügigen Grundstück von ca. 783 m2. Die Wohn- und Nutzfläche von ca. 188 m2 bietet Ihnen eine durchdachte und praktische Raumaufteilung, die für Familien ebenso ideal ist wie für Paare oder Einzelpersonen, die das Leben auf einer Ebene schützen.\n Beim Betreten des Hauses gelangen Sie in einen großzügigen Flur, von dem aus Sie bequem alle Räume des Erdgeschosses erreichen. Hier erwartet Sie ein einladendes und geräumiges Wohnzimmer, das mit einem gemütlichen elektrischen Kachelofen ausgestattet ist und den direkten Zugang zur Terrasse bietet der perfekte Ort, um warme Sommertage zu genie�en oder im Winter die Ruhe der Natur zu beobachten.', 'constructionyear': 1984, 'livingarea': 188, 'propertyarea': 783, 'details': 'Ausstattung;groer eigener Garten;praktischer Grundriss;Wohnrume auf einer Ebene;elektrischer Kachelofen im Wohnzimmer;Wohnzimmer mit Terrassenzugang;Nutzflche im Untergeschoss;zweites Badezimmer;Gasheizung;integrierte Garage;Carport', 'link': 'https://www.kleinanzeigen.de/s-anzeige/wohnen-im-gruenen-idyllisches-einfamilienhaus-in-sproeda/2953551344-208-11843'}
# static/images/title_0.jpg
# {'id': 1, 'title': 'Am Waldesrand 13, Petersroda', 'price': 375000, 'city': '06809 Sandersdorf-Brehna OT Petersroda', 'address': 'Am Waldesrand 13', 'lat': 51.5736911, 'lon': 12.2885077, 'ad_date': '01.01.2025', 'description': 'Provisionsfrei für Kaufende, Gäste-WC, Stufenlos ', 'constructionyear': 2019, 'livingarea': 113, 'propertyarea': 535, 'details': '-', 'link': 'https://mapio.net/expose/30732090/'}
# static/images/title_1.jpeg
# {'id': 2, 'title': 'Großzügiges Einfamilienhaus in Bitterfeld', 'price': 150000, 'city': '06749 Bitterfeld-Wolfen OT Bitterfeld', 'address': 'Semmelweisstraße 54', 'lat': 51.6389254, 'lon': 12.3173533, 'ad_date': '14.01.2025', 'description': 'Zum Verkauf steht ein Einfamilienhaus im Stadtbereich von Bitterfeld. Das Objekt wurde ca. 1939 errichtet. Über zwei Etagen stehen insgesamt 7 Zimmer, zwei Bäder und zwei Küchen zur Verfügung. Seit den 90er Jahren wurden in vielen Bereichen des Hauses fortlaufend Modernisierungen bereits durchgeführt. Zum Haus gehören eine Sommerlaube, eine Werkstatt, eine Garage, eine überdachte Terrasse.', 'constructionyear': 1939, 'livingarea': 120, 'propertyarea': 586, 'details': '-', 'link': 'https://www.kleinanzeigen.de/s-anzeige/grosszuegiges-einfamilienhaus-in-bitterfeld/2717550618-208-2272'}
# static/images/title_2.jpg
# {'id': 3, 'title': 'Großzügiges Einfamilienhaus', 'price': 249000, 'city': '06188 Landsberg', 'address': 'Geschwister-Scholl-Straße 14', 'lat': 51.5382844, 'lon': 12.1346563, 'ad_date': '12.10.2024', 'description': '06188 Landsberg OT Petersdorf;Teilsaniert;Ölheizung (Gas erschlossen) ans Abwassernetz angeschlossen Wintergarten (ca. 40 m²) freistehende Garage mit anschließenden Stallungen voll unterkellert Energieausweis vorhanden neuwertige Küche im Preis enthaltenBusanschluss (Entfernung: 10m)sofort bezugsfertig Besichtigungstermine nach telefonischer Rücksprache möglich (Tel.: 0163 60 45 450)', 'constructionyear': 1978, 'livingarea': 125, 'propertyarea': 1800, 'details': '-', 'link': 'https://www.kleinanzeigen.de/s-anzeige/grosszuegiges-einfamilienhaus/2889796074-208-17954'}
# static/images/title_3.jpg
# {'name': 'Staatsanwaltschaft Dessau', 'lat': 51.8344329, 'lon': 12.2352612, 'address': 'Ruststraße 5, 06844 Dessau-Roßlau'}
# {'name': 'Siemens Leipzig', 'lat': 51.3364826, 'lon': 12.3864534, 'address': 'Talstraße 4, 04103 Leipzig'}
# {'name': 'Petersroda', 'lat': 51.5701148, 'lon': 12.2850476}
# {'name': 'Roitzsch(Bitterf)', 'lat': 51.5707874, 'lon': 12.2631201}
# {'name': 'Bitterfeld', 'lat': 51.6226765, 'lon': 12.3156113}
# {'name': 'Delitzsch unt Bf', 'lat': 51.5269274, 'lon': 12.3371107}
# {'name': 'Delitzsch ob Bf', 'lat': 51.5223968, 'lon': 12.3344956}
# {'name': 'Greppin', 'lat': 51.6398653, 'lon': 12.2882299}
# {'name': 'Wolfen', 'lat': 51.6577822, 'lon': 12.2715358}
# {'name': 'Zschortau', 'lat': 51.4838133, 'lon': 12.357149}
# {'name': 'Rackwitz', 'lat': 51.4416376, 'lon': 12.3727939}
# {'name': 'Hohenroda', 'lat': 51.4990873, 'lon': 12.4203537}
# {'name': 'Brehna', 'lat': 51.5529302, 'lon': 12.2161055}

# %% [markdown]
# # Immoscout

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
import undetected_chromedriver as uc
from pprint import pprint
import wget
import os
import requests
import json
import shutil
import time

# %%
url = "https://www.immobilienscout24.de/expose/156890343?referrer=RESULT_LIST_LISTING&searchId=18e56ebd-95ea-3f3f-bfa6-282f9a621a0e&searchUrl=%2Fradius%2Fhaus-kaufen%3Fcenterofsearchaddress%3DBitterfeld-Wolfen%3B06749%3B%3B%3B%3B%3B%26geocoordinates%3D51.62619%3B12.32142%3B5.0&searchType=radius#/"
options = Options()
options.headless = True  # Enable headless mode for invisible operation
options = webdriver.ChromeOptions() 
options.add_argument("start-maximized")
driver = uc.Chrome(options=options)
#driver = webdriver.Chrome(options=options)

#with open('immo.json', encoding='utf-8') as f:
#    data = json.load(f)
#    f.close()


#immos_count = len(data["immos"])
#print("Current Length of Immos: ", immos_count)
#print("Last Immo ID: ", data["immos"][immos_count-1]["id"])
#print("New Immo ID: ", immos_count)


driver.get(url)

# %%
def getTitleImageUrl(driver):
    titles = driver.find_elements(By.CLASS_NAME,'gallery-element.is24-fullscreen-gallery-trigger')
    #titles = driver.find_elements(By.CLASS_NAME,'gallery-element')
    for title in titles:
        img_tag = title.get_attribute('outerHTML')
        print(img_tag)
        startsrc = img_tag.index('src=') + 5
        endsrc = img_tag.index('">')
        imgsrc = img_tag[startsrc:endsrc]
        print(imgsrc)
        return imgsrc
    
getTitleImageUrl(driver)
# Out:
# <img class="gallery-element is24-fullscreen-gallery-trigger" data-ng-non-bindable="" alt="Hausansicht" src="https://pictures.immobilienscout24.de/listings/14724a77-c89a-4854-89cc-2ce138ca12fe-1875378176.jpg/ORIG/legacy_thumbnail/1024x768/format/webp/quality/73">
# https://pictures.immobilienscout24.de/listings/14724a77-c89a-4854-89cc-2ce138ca12fe-1875378176.jpg/ORIG/legacy_thumbnail/1024x768/format/webp/quality/73
# 'https://pictures.immobilienscout24.de/listings/14724a77-c89a-4854-89cc-2ce138ca12fe-1875378176.jpg/ORIG/legacy_thumbnail/1024x768/format/webp/quality/73'

# %%
def clickTitleImageToGetImageGallery(driver):
    driver.find_element(By.CLASS_NAME,'button.is24-fullscreen-gallery-trigger').click()


clickTitleImageToGetImageGallery(driver)

# %%
img_list = []
def getFirstImageUrlFromGallery(driver):
    titles = driver.find_elements(By.CLASS_NAME,'imageContainer_0wG-W')
    #titles = driver.find_elements(By.CLASS_NAME,'gallery-element')
    for title in titles:
        print(title.text)
        imgsrc = title.get_attribute('innerHTML')
        imgsrc = imgsrc.replace("<img src=\"","")
        #print(imgsrc)
        imgsrc = imgsrc.split("\"")[0]
        img_list.append(imgsrc)
        print(imgsrc)
        
getFirstImageUrlFromGallery(driver)
print(img_list)
# Out:
# https://pictures.immobilienscout24.de/listings/14724a77-c89a-4854-89cc-2ce138ca12fe-1875378176.jpg/ORIG/resize/1106x830%3E/format/webp/quality/73
#
# https://pictures.immobilienscout24.de/listings/f8504bc5-a51b-4bd3-a6ce-ebfa78355c36-1875378186.jpg/ORIG/resize/1106x830%3E/format/webp/quality/73
#
# https://pictures.immobilienscout24.de/listings/dd982dbe-483c-4574-a02e-403c98234ac1-1875378499.jpg/ORIG/resize/1106x830%3E/format/webp/quality/73
# ['https://pictures.immobilienscout24.de/listings/14724a77-c89a-4854-89cc-2ce138ca12fe-1875378176.jpg/ORIG/resize/1106x830%3E/format/webp/quality/73', 'https://pictures.immobilienscout24.de/listings/f8504bc5-a51b-4bd3-a6ce-ebfa78355c36-1875378186.jpg/ORIG/resize/1106x830%3E/format/webp/quality/73', 'https://pictures.immobilienscout24.de/listings/dd982dbe-483c-4574-a02e-403c98234ac1-1875378499.jpg/ORIG/resize/1106x830%3E/format/webp/quality/73']

# %%
thumbnail_list = []
def getAllThumbnailImageUrlFromGallery(driver):

    titles = driver.find_elements(By.CLASS_NAME,'thumbnail_8uYUI ')
    #titles = driver.find_elements(By.CLASS_NAME,'gallery-element')
    for title in titles:
        img_tag = title.get_attribute('innerHTML')
        print(img_tag)
        startsrc = img_tag.index('src=') + 5
        print(startsrc)
        endsrc = img_tag.index('">',startsrc,len(img_tag))
        print(endsrc)
        
        imgsrc = img_tag[startsrc:endsrc]
        imgsrc = imgsrc.split("\" ")[0]
        print(imgsrc)
        thumbnail_list.append(imgsrc)
    
getAllThumbnailImageUrlFromGallery(driver)
print(thumbnail_list)
# Out:
# <div role="button" tabindex="0" data-testid="thumbnail-wrapper-0"><div class="padding-horizontal-xs"><img src="https://pictures.immobilienscout24.de/listings/14724a77-c89a-4854-89cc-2ce138ca12fe-1875378176.jpg/ORIG/legacy_thumbnail/80x60/format/webp/quality/73" class="thumbnailImage_ZbUzF" alt="Hausansicht"></div></div>
# 111
# 307
# https://pictures.immobilienscout24.de/listings/14724a77-c89a-4854-89cc-2ce138ca12fe-1875378176.jpg/ORIG/legacy_thumbnail/80x60/format/webp/quality/73
# <div role="button" tabindex="0" data-testid="thumbnail-wrapper-1"><div class="padding-horizontal-xs"><img src="https://pictures.immobilienscout24.de/listings/f8504bc5-a51b-4bd3-a6ce-ebfa78355c36-1875378186.jpg/ORIG/legacy_thumbnail/80x60/format/webp/quality/73" class="thumbnailImage_ZbUzF" alt="Hausansicht2"></div></div>
# 111
# 308
# https://pictures.immobilienscout24.de/listings/f8504bc5-a51b-4bd3-a6ce-ebfa78355c36-1875378186.jpg/ORIG/legacy_thumbnail/80x60/format/webp/quality/73
# <div role="button" tabindex="0" data-testid="thumbnail-wrapper-2"><div class="padding-horizontal-xs"><img src="https://pictures.immobilienscout24.de/listings/d625734b-ec88-43ab-a88a-0cd59370cb58-1875378198.jpg/ORIG/legacy_thumbnail/80x60/format/webp/quality/73" class="thumbnailImage_ZbUzF" alt="Hausansicht 3"></div></div>
# 111
# 309
# https://pictures.immobilienscout24.de/listings/d625734b-ec88-43ab-a88a-0cd59370cb58-1875378198.jpg/ORIG/legacy_thumbnail/80x60/format/webp/quality/73
# <div role="button" tabindex="0" data-testid="thumbnail-wrapper-3"><div class="padding-horizontal-xs"><img src="https://pictures.immobilienscout24.de/listings/af6af2d8-0be6-41bc-9bb8-7fae7d5c9862-1875378209.jpg/ORIG/legacy_thumbnail/80x60/format/webp/quality/73" class="thumbnailImage_ZbUzF" alt="Hausansicht4"></div></div>
# 111
# 308
# https://pictures.immobilienscout24.de/listings/af6af2d8-0be6-41bc-9bb8-7fae7d5c9862-1875378209.jpg/ORIG/legacy_thumbnail/80x60/format/webp/quality/73
# <div role="button" tabindex="0" data-testid="thumbnail-wrapper-4"><div class="padding-horizontal-xs"><img src="https://pictures.immobilienscout24.de/listings/a30c7b2c-9751-48fd-82ff-a4448ed4b9bb-1875378219.jpg/ORIG/legacy_thumbnail/80x60/format/webp/quality/73" class="thumbnailImage_ZbUzF" alt="Ansicht Terrasse"></div></div>
# 111
# 312
# https://pictures.immobilienscout24.de/listings/a30c7b2c-9751-48fd-82ff-a4448ed4b9bb-1875378219.jpg/ORIG/legacy_thumbnail/80x60/format/webp/quality/73
# <div role="button" tabindex="0" data-testid="thumbnail-wrapper-5"><div class="padding-horizontal-xs"><img src="https://pictures.immobilienscout24.de/listings/e2d078ad-a4f6-4600-bc03-1e9d10aff3b9-1875378234.jpg/ORIG/legacy_thumbnail/80x60/format/webp/quality/73" class="thumbnailImage_ZbUzF" alt="Einfahrt"></div></div>
# 111
# 304
# https://pictures.immobilienscout24.de/listings/e2d078ad-a4f6-4600-bc03-1e9d10aff3b9-1875378234.jpg/ORIG/legacy_thumbnail/80x60/format/webp/quality/73
# <div role="button" tabindex="0" data-testid="thumbnail-wrapper-6"><div class="padding-horizontal-xs"><img src="https://pictures.immobilienscout24.de/listings/926a4993-6eb4-407a-b0d6-03faa1feee01-1875378252.jpg/ORIG/legacy_thumbnail/80x60/format/webp/quality/73" class="thumbnailImage_ZbUzF" alt="Garage"></div></div>
# 111
# 302
# https://pictures.immobilienscout24.de/listings/926a4993-6eb4-407a-b0d6-03faa1feee01-1875378252.jpg/ORIG/legacy_thumbnail/80x60/format/webp/quality/73
# <div role="button" tabindex="0" data-testid="thumbnail-wrapper-7"><div class="padding-horizontal-xs"><img src="https://pictures.immobilienscout24.de/listings/3bbeafe7-5363-49da-8516-dcc79bcd36ee-1875378260.jpg/ORIG/legacy_thumbnail/80x60/format/webp/quality/73" class="thumbnailImage_ZbUzF" alt="Nebengelass"></div></div>
# 111
# 307
# https://pictures.immobilienscout24.de/listings/3bbeafe7-5363-49da-8516-dcc79bcd36ee-1875378260.jpg/ORIG/legacy_thumbnail/80x60/format/webp/quality/73
# <div role="button" tabindex="0" data-testid="thumbnail-wrapper
jpg/ORIG/legacy_thumbnail/80x60/format/webp/quality/73" class="thumbnailImage_ZbUzF" alt="Werkstatt"></div></div>
# 112
# 306
# https://pictures.immobilienscout24.de/listings/dd982dbe-483c-4574-a02e-403c98234ac1-1875378499.jpg/ORIG/legacy_thumbnail/80x60/format/webp/quality/73
# ['https://pictures.immobilienscout24.de/listings/14724a77-c89a-4854-89cc-2ce138ca12fe-1875378176.jpg/ORIG/legacy_thumbnail/80x60/format/webp/quality/73', 'https://pictures.immobilienscout24.de/listings/f8504bc5-a51b-4bd3-a6ce-ebfa78355c36-1875378186.jpg/ORIG/legacy_thumbnail/80x60/format/webp/quality/73', 'https://pictures.immobilienscout24.de/listings/d625734b-ec88-43ab-a88a-0cd59370cb58-1875378198.jpg/ORIG/legacy_thumbnail/80x60/format/webp/quality/73', 'https://pictures.immobilienscout24.de/listings/af6af2d8-0be6-41bc-9bb8-7fae7d5c9862-1875378209.jpg/ORIG/legacy_thumbnail/80x60/format/webp/quality/73', 'https://pictures.immobilienscout24.de/listings/a30c7b2c-9751-48fd-82ff-a4448ed4b9bb-1875378219.jpg/ORIG/legacy_thumbnail/80x60/format/webp/quality/73', 'https://pictures.immobilienscout24.de/listings/e2d078ad-a4f6-4600-bc03-1e9d10aff3b9-1875378234.jpg/ORIG/legacy_thumbnail/80x60/format/webp/quality/73', 'https://pictures.immobilienscout24.de/listings/926a4993-6eb4-407a-b0d6-03faa1feee01-1875378252.jpg/ORIG/legacy_thumbnail/80x60/format/webp/quality/73', 'https://pictures.immobilienscout24.de/listings/3bbeafe7-5363-49da-8516-dcc79bcd36ee-1875378260.jpg/ORIG/legacy_thumbnail/80x60/format/webp/quality/73', 'https://pictures.immobilienscout24.de/listings/fd742e79-04d1-4d07-b806-23e2825becf8-1875378273.jpg/ORIG/legacy_thumbnail/80x60/format/webp/quality/73', 'https://pictures.immobilienscout24.de/listings/7ea7bd2b-3667-413d-801e-fb196cd8a50d-1875378281.jpg/ORIG/legacy_thumbnail/80x60/format/webp/quality/73', 'https://pictures.immobilienscout24.de/listings/1cf5228e-58c5-4190-9eae-3e997144a36a-1875378298.jpg/ORIG/legacy_thumbnail/80x60/format/webp/quality/73', 'https://pictures.immobilienscout24.de/listings/1c3e2569-08c6-4506-b5f7-3edc3a2f7f66-1875378313.jpg/ORIG/legacy_thumbnail/80x60/format/webp/quality/73', 'https://pictures.immobilienscout24.de/listings/3faac2a6-6599-4d90-a402-91dfdee46e57-1875378329.jpg/ORIG/legacy_thumbnail/80x60/format/webp/quality/73', 'https://pictures.immobilienscout24.de/listings/0eecf5b0-981e-4ff6-95a4-39513328365e-1875378344.jpg/ORIG/legacy_thumbnail/80x60/format/webp/quality/73', 'https://pictures.immobilienscout24.de/listings/37ea98ba-8ad4-43f7-87c0-b60eb184cf62-1875378365.jpg/ORIG/legacy_thumbnail/80x60/format/webp/quality/73', 'https://pictures.immobilienscout24.de/listings/3a4cc728-bfb7-4f62-8fb1-18edcc6b1970-1875378388.jpg/ORIG/legacy_thumbnail/80x60/format/webp/quality/73', 'https://pictures.immobilienscout24.de/listings/bee8aac6-4a4a-42cd-af0f-c12d683483f6-1875378406.jpg/ORIG/legacy_thumbnail/80x60/format/webp/quality/73', 'https://pictures.immobilienscout24.de/listings/ac1aaebf-63a3-410e-bfe8-529c25c849e7-1875378424.jpg/ORIG/legacy_thumbnail/80x60/format/webp/quality/73', 'https://pictures.immobilienscout24.de/listings/d534bca4-713c-46e5-ae71-be0e65c8c7b3-1875378442.jpg/ORIG/legacy_thumbnail/80x60/format/webp/quality/73', 'https://pictures.immobilienscout24.de/listings/fcb84d8c-3de5-448e-bfbd-1d1faa824be4-1875378458.jpg/ORIG/legacy_thumbnail/80x60/format/webp/quality/73', 'https://pictures.immobilienscout24.de/listings/2521196c-8c5c-4a82-b621-d9adc6ed49c7-1875378480.jpg/ORIG/legacy_thumbnail/80x60/format/webp/quality/73', 'https://pictures.immobilienscout24.de/listings/dd982dbe-483c-4574-a02e-403c98234ac1-1875378499.jpg/ORIG/legacy_thumbnail/80x60/format/webp/quality/73']

# %%
origsize = '1106x830'
thumbnail = 'https://pictures.immobilienscout24.de/listings/af6af2d8-0be6-41bc-9bb8-7fae7d5c9862-1875378209.jpg/ORIG/legacy_thumbnail/80x60/format/webp/quality/73'
thumbnail = 'https://pictures.immobilienscout24.de/listings/af6af2d8-0be6-41bc-9bb8-7fae7d5c9862-1875378209.jpg/ORIG/resize/1106x830/format/webp/quality/100'

# %%
def getOrigSizePath(src):
    src = src.split("/ORIG/")[1]
    print(src)
    return src
    
high_quality_path = getOrigSizePath(img_list[0])


for thumbnail in thumbnail_list:
    thumbnail = thumbnail.split("/ORIG/")[0]
    print(thumbnail)
    image_paths.append(thumbnail)
    thumbnail = thumbnail + "/ORIG/" + high_quality_path
    print(thumbnail)

print(image_paths)
# Out:
# resize/1106x830%3E/format/webp/quality/73
# https://pictures.immobilienscout24.de/listings/14724a77-c89a-4854-89cc-2ce138ca12fe-1875378176.jpg
# https://pictures.immobilienscout24.de/listings/14724a77-c89a-4854-89cc-2ce138ca12fe-1875378176.jpg/ORIG/resize/1106x830%3E/format/webp/quality/73
# https://pictures.immobilienscout24.de/listings/f8504bc5-a51b-4bd3-a6ce-ebfa78355c36-1875378186.jpg
# https://pictures.immobilienscout24.de/listings/f8504bc5-a51b-4bd3-a6ce-ebfa78355c36-1875378186.jpg/ORIG/resize/1106x830%3E/format/webp/quality/73
# https://pictures.immobilienscout24.de/listings/d625734b-ec88-43ab-a88a-0cd59370cb58-1875378198.jpg
# https://pictures.immobilienscout24.de/listings/d625734b-ec88-43ab-a88a-0cd59370cb58-1875378198.jpg/ORIG/resize/1106x830%3E/format/webp/quality/73
# https://pictures.immobilienscout24.de/listings/af6af2d8-0be6-41bc-9bb8-7fae7d5c9862-1875378209.jpg
# https://pictures.immobilienscout24.de/listings/af6af2d8-0be6-41bc-9bb8-7fae7d5c9862-1875378209.jpg/ORIG/resize/1106x830%3E/format/webp/quality/73
# https://pictures.immobilienscout24.de/listings/a30c7b2c-9751-48fd-82ff-a4448ed4b9bb-1875378219.jpg
# https://pictures.immobilienscout24.de/listings/a30c7b2c-9751-48fd-82ff-a4448ed4b9bb-1875378219.jpg/ORIG/resize/1106x830%3E/format/webp/quality/73
# https://pictures.immobilienscout24.de/listings